# %%
import pandas as pd
data = pd.read_excel('ITBPI.xlsx')
data
# Out:
#             프로젝트번호                                              프로젝트명  상태 코드  \
# 0   P2021-05012-01                     [어울림광장] 주택담보대출 사후관리화면상 상세주소 표시      1
# 1   P2021-04993-01                                    통합단말 2241 화면 개선      1
# 2   P2021-03644-02     [시드니] 9041화면 심사역구분에 지점장, Compliance Officer 추가      1
# 3   P2021-03814-02                     [인니] 펌뱅킹환율조회배치 수정 (LG CNS 펌뱅킹)      1
# 4   P2021-04985-01                                 비대면소액송금 한도제한 채널 추가      1
# ..             ...                                                ...    ...
# 95  P2021-03968-01  [카작] Request for amendment of Internet Banking...      0
# 96  P2021-05060-01                          高미사용율 가계 신용 유동성한도대출 감액 개발      0
# 97  P2021-04815-01                               비대면 신탁 운용지시 이행 행위 보완      0
# 98  P2021-04631-01                                R/A평가 ,CDD화면 보완 신청       0
# 99  P2021-03624-01                  [CORE] 배치작업 처리내역 관리 테이블 및 프로그램 개선      5
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'NanumGothic'

plt.figure(figsize=(20,10))
sns.countplot(y='상태',data=data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='상태'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(y='PM부서명',data=data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='PM부서명'>

# %%
plt.figure(figsize=(20,20))
sns.countplot(y='PM성명',data=data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='PM성명'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='프로그램변경유무',data=data)
# Out:
# <AxesSubplot:xlabel='프로그램변경유무', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='품질검증대상유무',data=data)
# Out:
# <AxesSubplot:xlabel='품질검증대상유무', ylabel='count'>

# %%
data['패스트체크인여부'].fillna('N')
# Out:
# 0     Y
# 1     Y
# 2     N
# 3     N
# 4     Y
#      ..
# 95    Y
# 96    Y
# 97    Y
# 98    Y
# 99    Y
# Name: 패스트체크인여부, Length: 100, dtype: object

# %%
plt.figure(figsize=(10,5))
sns.countplot(data['패스트체크인여부'].fillna('N'), hue=data['체크인 체크여부'])
# Out:
# <AxesSubplot:xlabel='패스트체크인여부', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='인수테스트대상여부',hue='인수테스트진행여부',data=data)
# Out:
# <AxesSubplot:xlabel='인수테스트대상여부', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='BA결재여부',data=data)
# Out:
# <AxesSubplot:xlabel='BA결재여부', ylabel='count'>
